# %% [markdown]
# # Loading and Preprocessing Data

# %%
import pandas as pd

# %% [markdown]
# # Reading CSV file

# %%
# Reading CSV file into a DataFrame
df=pd.read_csv("C:/Users/DELL/Desktop/TextBasedAnalysis/Arts_Crafts_and_sewing_5.csv")
# Displaying a random sample of 20 rows from the DataFrame
df.sample(20)
# Out:
#         overall  verified      reviewerID        asin  \
# 271839        5      True  A1LGR60X7C7XK9  B009LIOFYY
# 429635        5      True  A2K8W77RIPF169  B001CE5DPK
# 49244         4      True  A3V8LM88C2H6KO  B000XZW32K
# 40791         5      True  A1IG3JJUDX1IZK  B000W5R6UA
# 240681        5      True   ASX2QEYZICOKZ  B005V9V6L2
# 278831        5      True  A3LUOEPUGF50VO  B00AWMFR86
# 83276         5      True  A39GJJT0H2BZH9  B00177X9OO
# 48306         4      True  A3F1798DQORRM1  B000XZTOCC
# 290080        5      True  A18D1949K5C029  B00BWJCCI6
# 491           5      True  A32UJ87I6YGQMJ  B00002X2FX
# 125186        4      True  A1MA10XWATMD3O  B001705SVS
# 63102         5      True  A2845BYVKZYVZG  B0011459EG
# 382911        5      True   A7HPEU5X7XNGK  B011NO3OXG
# 412543        3     False  A3H6IPLMWN4MH6  B01F31ABGI
# 356958        5     False  A1NS6O584WD5FJ  B00P0J7R70
# 455036        5      True   AKD9VDVY93MB4  B009EE2TVQ
# 8667          4      True  A19I0GDI45NXEU  B0007CIOVI
# 172244        5      True   A365AGJQDQ971  B0027ACBKI
# 478393        5      True  A1WCLV2PPQK28I  B00NJ0OV6W
# 67974         5     False  A1K6NABKA6C9GI  B000NJT4C8
#
#                                                reviewText  \
# 271839                                        great price
# 429635                                    awesome product
# 49244   Nice stencils. Not super thick, but they work....
# 40791                                 Best on the market.
# 240681  Great Pens....Beautiful Color.....Smooth to co...
# 278831                                   love it.  Thanks
# 83276   Bought these for my first foray into these typ...
# 48306          I would buy again. Good yarn for projects.
# 290080  I absolutely love this machine, I stubbled acr...
# 491                             good product, great price
# 125186                                           It works
# 63102                                                  OK
# 382911  These wick holders are essential when making c...
# 412543  I bought this set mostly for the variety of in...
# 356958  This is coming from a beginning sewing enthusi...
# 455036  Are what they say they are, Wooden sticks just...
# 8667                                               Works.
# 172244  I like the sturdiness and usefulness of this b...
# 478393  This will be very hand for all my sewing and m...
# 67974   lots of fun.  beware that you have to mix colo...
#
#                                                   summary
# 271839                                         Five Stars
# 429635                                         Five Stars
# 49244                      Not super thick, but they work
# 40791                                         recommended
# 240681                                         Five Stars
# 278831                                         Five Stars
# 83276                 Good quality for a reasonable price
# 48306                              Good yarn for projects
# 290080                                               LOVE
# 491                                            Five Stars
# 125186                                         Four Stars
# 63102                                          Five Stars
# 382911                           They worked great for me
# 412543  Okay starter set - lots of colors and some use...
# 356958               Great sewing machine, very versatile
# 455036                                        Great price
# 8667                                               Works.
# 172244                                  Handy Box to Have
# 478393                                         Five Stars
# 67974                                        lots of fun.

# %%
#!pip install scikit-learn

# %% [markdown]
# # Sentiment Analysis Setup

# %%
# Importing the preprocessing module from the scikit-learn library
from sklearn import preprocessing
# Importing the Natural Language Toolkit (NLTK)
import nltk
# Downloading the opinion lexicon dataset from NLTK
nltk.download('opinion_lexicon')
# Importing the opinion_lexicon dataset from the NLTK corpus module
from nltk.corpus import opinion_lexicon
# Importing the word_tokenize function from the NLTK tokenize module
from nltk.tokenize import word_tokenize
# Printing the total number of words in the opinion_lexicon dataset
print('Total number of words in opinion lexicon', len(opinion_lexicon.words()))
# Printing examples of positive words in the opinion_lexicon dataset
print('Examples of positive words in opinion lexicon',
      opinion_lexicon.positive()[:10])
# Printing examples of negative words in the opinion_lexicon dataset
print('Examples of negative words in opinion lexicon',
      opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon 6789
# Examples of positive words in opinion lexicon ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %% [markdown]
# # Applying Sentiment Analysis

# %%
# Let's create a dictionary which we can use for scoring our review text

# Downloading punkt from NLTK library
nltk.download('punkt')

# Renaming the column 'reviewText' to 'Modules' in the DataFrame
df.rename(columns={"reviewText": "Modules"}, inplace=True)

# Assigning positive and negative scores
pos_score = 1
neg_score = -1

# Initializing an empty dictionary
word_dict = {}
 
# Adding the positive words to the dictionary
for word in opinion_lexicon.positive():
        word_dict[word] = pos_score
      
# Adding the negative words to the dictionary
for word in opinion_lexicon.negative():
        word_dict[word] = neg_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Data Exploration

# %% [markdown]
# # Function to Calculate Sentiment Score using Bing Liu's Lexicon

# %%
#Creating a fuunction text
def bing_liu_score(Modules):
    #Initializing the sentiment score
    sentiment_score = 0
    #Tokenizing the input text into words and convert them to lowercase
    bag_of_words = word_tokenize(Modules.lower())
     # creating loop to check each word in the bag of words
    for word in bag_of_words:
        #Checking if the word exists in the sentiment dictionary
        if word in word_dict:
            # If the word exist, adding its sentiment score to the sentiment score
            sentiment_score += word_dict[word]
    return sentiment_score  #Returning the sentiment score for the text

# %% [markdown]
# # Data Preprocessing and Sentiment Analysis

# %%
# Fill NaN values in the 'text' column
df['Modules'].fillna('no review', inplace=True)
#creating new column 'Bing_Liu_Score' to store the scores by applying  bing_liu_score to calculate sentiment scores for Module column
df['Bing_Liu_Score'] = df['Modules'].apply(bing_liu_score)

# %% [markdown]
# # Displaying Selected Columns for Analysis

# %%
# Displaying the first 5 rows of the DataFrame with few columns
df[['overall','reviewerID',"Modules", 'Bing_Liu_Score']].head(5)
# Out:
#    overall      reviewerID                                            Modules  \
# 0        4   AIE8N9U317ZBM                Contains some interesting stitches.
# 1        5  A3ECOW0TWLH9V6  I'm a fairly experienced knitter of the one-co...
# 2        4  A278N8QX9TY2OS  Great book but the index is terrible. Had to w...
# 3        5  A123W8HIK76XCN  I purchased the Kindle edition which is incred...
# 4        5  A2A6MZ2QB4AE0L  Very well laid out and very easy to read.\n\nT...
#
#    Bing_Liu_Score
# 0               1
# 1              22
# 2               0
# 3               4
# 4               5

# %% [markdown]
# # Grouping and Aggregating Sentiment Scores

# %%
# Grouping the DataFrame by the 'overall' column and calculating the mean of 'Bing_Liu_Score' for each group
df.groupby('overall').agg({'Bing_Liu_Score':'mean'})
# Out:
#          Bing_Liu_Score
# overall
# 1             -0.255049
# 2              0.566098
# 3              1.158796
# 4              2.027999
# 5              2.129986
