# %% [markdown]
# # Loading the dataset

# %%
# Loading Data set using pandas.
import pandas as pd  # Importing pandas as pd
file="C:/Users/DELL/Desktop/TextBasedAnalysis/detailed_reviews.csv" # File Path
df=pd.read_csv(file)
# Fill NaN values in 'comments' column with empty strings
df['comments'] = df['comments'].fillna('')
# Using head Meathod to Print Top 20 Rows
df.head(20)
# Out:
#     listing_id        id        date  reviewer_id reviewer_name  \
# 0         2595     17857  2009-11-21        50679          Jean
# 1         2595     19176  2009-12-05        53267          Cate
# 2         2595     19760  2009-12-10        38960         Anita
# 3         2595     34320  2010-04-09        71130       Kai-Uwe
# 4         2595     46312  2010-05-25       117113        Alicia
# 5         2595   1238204  2012-05-07      1783688        Sergey
# 6         2595   1293632  2012-05-17      1870771          Loïc
# 7         2595   2022498  2012-08-18      2124102       Melanie
# 8         2595   4682989  2013-05-20       496053          Eric
# 9         2595  13193832  2014-05-21     13685934        Gerald
# 10        2595  15515108  2014-07-10     10781357       Richard
# 11        2595  20372242  2014-09-28      4212558        Carson
# 12        2595  20937971  2014-10-07     13460520       Michael
# 13        2595  21464102  2014-10-18     16584002         Kitty
# 14        2595  28794060  2015-03-30     27436102        Kellie
# 15        2595  30430122  2015-04-21      6429364         Sonya
# 16        2595  32532759  2015-05-19     12146524       Michiel
# 17        2595  47785650  2015-09-21     12885233           Lin
# 18        2595  48764464  2015-09-28     18636130          Alex
# 19        2595  69547296  2016-04-11     16512817          Gary
#
#                                              comments
# 0   Notre séjour de trois nuits.\r<br/>Nous avons ...
# 1                                   Great experience.
# 2   I've stayed with my friend at the Midtown Cast...
# 3   We've been staying here for about 9 nights, en...
# 4   We had a wonderful stay at Jennifer's charming...
# 5   Hi to everyone!\r<br/>Would say our greatest c...
# 6   Jennifer was very friendly and helpful, and he...
# 7   This apartment is like a real castle old and u...
# 8   Jennifer's place was in a great midtown locati...
# 9   Jennifer is a very nice host. Everything is cl...
# 10  This is a cute studio in a wonderful location ...
# 11  A great location, a very comfortable space and...
# 12  Jennifer's place is cozy and a short walking d...
# 13  We hebben genoten van ons verblijf in het appa...
# 14  Jennifer was very good at communicating with u...
# 15  I love this space.  It is truly a gem in the h...
# 16  This was our first Airbnb experience, and Jenn...
# 17  Great location, in the middle of everything. T...
# 18  Jennifer was without doubt an amazing host, sh...
# 19  Jennifer was an unbelievable host! Great commu...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Printing column names

# %%
# Printing Column Names 
df.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %% [markdown]
# # Printing Data Types of Columns

# %%
# Printing Data Types of the Columns
df.dtypes
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %% [markdown]
# # Applying Info Method

# %%
# Printing the Basic Information of the Data Set.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001295 entries, 0 to 1001294
# Data columns (total 6 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   listing_id     1001295 non-null  int64
#  1   id             1001295 non-null  int64
#  2   date           1001295 non-null  object
#  3   reviewer_id    1001295 non-null  int64
#  4   reviewer_name  1001292 non-null  object
#  5   comments       1001039 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 45.8+ MB

# %% [markdown]
# # Printing Statistical Information

# %%
# Printing the Statistical Information of the Data Set.
df.describe()
# Out:
#          listing_id            id   reviewer_id
# count  1.001295e+06  1.001295e+06  1.001295e+06
# mean   1.033923e+17  3.917054e+17  1.516902e+08
# std    2.554456e+17  3.999901e+17  1.470068e+08
# min    2.595000e+03  3.149000e+03  1.000000e+00
# 25%    9.116018e+06  3.428725e+08  3.009433e+07
# 50%    2.573402e+07  4.222015e+17  1.001318e+08
# 75%    4.905188e+07  7.790153e+17  2.373305e+08
# max    1.054376e+18  1.062461e+18  5.539802e+08

# %% [markdown]
# # Adding a New Column

# %%
# Adding a new column to store length of the text.
df['length']=df['comments'].str.len()
df.describe()
# Out:
#          listing_id            id   reviewer_id        length
# count  1.001295e+06  1.001295e+06  1.001295e+06  1.001039e+06
# mean   1.033923e+17  3.917054e+17  1.516902e+08  2.575231e+02
# std    2.554456e+17  3.999901e+17  1.470068e+08  2.621070e+02
# min    2.595000e+03  3.149000e+03  1.000000e+00  1.000000e+00
# 25%    9.116018e+06  3.428725e+08  3.009433e+07  8.700000e+01
# 50%    2.573402e+07  4.222015e+17  1.001318e+08  1.850000e+02
# 75%    4.905188e+07  7.790153e+17  2.373305e+08  3.390000e+02
# max    1.054376e+18  1.062461e+18  5.539802e+08  6.018000e+03

# %% [markdown]
# # Applying describer Method

# %%
# Using describe Method
df.describe(include='O')
# Out:
#               date reviewer_name comments
# count      1001295       1001292  1001039
# unique        4954        119518   962980
# top     2023-09-04         David        .
# freq          1737          7039     1167

# %% [markdown]
# # Data Visualization

# %%
# Importing matplotlib Package
import matplotlib.pyplot as plt
# Assuming 'length' as a Target Column
df['length'].plot(label='Length')
# Adding legend
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.legend()
# Display the plot
plt.show()

# %% [markdown]
# # Ploting a Box Plot

# %%
df['length'].plot(kind='box', vert=False)
# Adding labels and title
plt.xlabel('Length')
plt.title('Horizontal Box Plot of Length')
# Showing the plot
plt.show()

# %% [markdown]
# # Creating a Histogram

# %%
# Creating a Histogram
df['length'].plot(kind='hist',bins=30)
plt.xlabel('Length')
# Out:
# Text(0.5, 0, 'Length')

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='listing_id', bins=30, kde=True)
plt.title('Distribution of listing_id')
plt.xlabel('listing_id')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Pre-Processing Pipeline

# %%
# !pip install regex

# %%
# Regex to Pull Out Words
import regex as re
def tokenize(text):return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text) # Function To Tokenize

# %% [markdown]
# # Tokenizing the Given Text

# %%
# Toknizing the Given Text
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# # Using nltk Package

# %%
# Installing nltk Package
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\dell\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\dell\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\dell\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dell\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %% [markdown]
# # Importing NLTK Package and Downloading Stopwords

# %%
import nltk  # Importing nltk Package
from nltk.tokenize import word_tokenize

nltk.download('punkt') 
nltk.download('stopwords')
# Downloading list of English Stop Words
stopwords = set(nltk.corpus.stopwords.words('english'))  
print(stopwords)
# Out:
# {'isn', 'is', 'each', 'she', 'd', 'while', 'after', 'above', 'on', 'who', "haven't", 'but', "mustn't", "you're", 'during', 'such', 'been', 'i', 'a', "that'll", 'you', 'same', 'didn', 'were', 'so', 'am', 'both', 'not', 'myself', 'himself', 'mustn', 'needn', 'through', 'weren', 'under', 'in', 'ma', 'won', 'does', 'they', 'against', 'very', 'over', 'now', 'our', "she's", 'themselves', "needn't", 'shouldn', 'y', 'to', 'other', 'aren', 'hadn', 'any', 'the', 'hers', 'why', 'ourselves', 're', 'shan', 'their', 'an', 'ain', "should've", 'there', 'some', 'own', "wouldn't", 'as', 'couldn', 'did', 'him', 'do', 'until', 'are', 'o', 'off', 'yours', "it's", 'if', "don't", 'too', 'before', 'your', 'has', 'between', "aren't", 'doesn', "isn't", 'wouldn', 'by', 'all', 'which', "mightn't", 'those', 'wasn', 'we', 'them', 'once', 'from', 'he', 's', 'itself', 've', 'here', 'my', 'how', "hasn't", 'these', 'whom', 'this', 'doing', 'and', 'being', 'most', "you'd", "doesn't", 'what', 'his', 'yourselves', "shouldn't", 'had', 'was', "couldn't", "won't", 'me', "you'll", 'yourself', 'with', 'be', "shan't", 'below', 'mightn', 'will', 'nor', 'have', 'just', 'down', 'hasn', 'no', 'or', 'its', 'can', 'haven', 'than', 'herself', 't', 'when', 'her', "wasn't", 'few', 'more', 'that', 'theirs', 'up', 'don', 'it', "you've", 'into', 'out', 'of', 'further', "didn't", 'm', 'ours', 'about', 'll', 'again', 'then', 'where', "hadn't", 'should', "weren't", 'having', 'because', 'at', 'only', 'for'}
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Making a PipeLine

# %%
# making a “pipeline"
pipeline = [str.lower, tokenize]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# # Runing PipeLine

# %%
# Runing the pipeline
df['tokens'] = df['comments'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# # Counting Tokens

# %%
#counting the tokens
df['num_tokens'] = df['tokens'].dropna().map(len)
df.tail()
# Out:
#                   listing_id                   id        date  reviewer_id  \
# 1001290  1040414934125590651  1059503510468077517  2024-01-01     68025044
# 1001291  1040414934125590651  1059514700195940644  2024-01-01    474638263
# 1001292  1040414934125590651  1059520113012955704  2024-01-01     87877822
# 1001293  1040414934125590651  1059525245555645887  2024-01-01    465647297
# 1001294  1040414934125590651  1059543893215659250  2024-01-01    153808333
#
#         reviewer_name                                           comments  \
# 1001290      Nataccia  It’s was okay for the one night stay. The bath...
# 1001291       Letícia  The stay was very good, I would stay again if ...
# 1001292       Zachary  We loved everything about our stay here! Very ...
# 1001293        Jadson  Great location in the heart of Manhattan, clos...
# 1001294    Shantinque  Perfect sized room for however long you want. ...
#
#                                                     tokens  num_tokens
# 1001290  [it, s, was, okay, for, the, one, night, stay,...        14.0
# 1001291  [the, stay, was, very, good, i, would, stay, a...        11.0
# 1001292  [we, loved, everything, about, our, stay, here...        31.0
# 1001293  [great, location, in, the, heart, of, manhatta...        16.0
# 1001294  [perfect, sized, room, for, however, long, you...        32.0

# %% [markdown]
# # Word Frequency Analysis

# %%
from collections import Counter # Importing Counter from Collections
tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens) # Counting tokens
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# # Adding New Data

# %%
# Adding New Data to the Current Count
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# # Counting Word Repetations

# %%
# Counting the Word Repetations
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('the', 1982757), ('and', 1944870), ('a', 1243312), ('to', 1196103), ('was', 1050491)]

# %% [markdown]
# #  Using word frequency in it’s own dataframe for analysis

# %%
# Using word frequency in it’s own dataframe for analysis
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq']) 
freq_df = freq_df.query('freq >= 1') # Use it to Prevent Worlds that are infrequent
freq_df.index.name = 'token'

# %% [markdown]
# # Sorting Based on Frequency

# %%
# Let,s sort Based on Frequency and display
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#           freq
# token
# the    1982757
# and    1944870
# a      1243312
# to     1196103
# was    1050491
# is      782572
# in      708023
# i       594951
# very    576137
# great   535672

# %% [markdown]
# # Printing Statistical Data

# %%
# Printing the Statistical Data
freq_df.describe()
# Out:
#                freq
# count  1.992140e+05
# mean   2.299794e+02
# std    9.440352e+03
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    5.000000e+00
# max    1.982757e+06

# %% [markdown]
# # Aplying Bar Chat

# %%
#bar chart 
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8)) # Only for Top 15 Words 
ax.invert_yaxis() 
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words') # Legend
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
# Installing Wordcloud Package
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\dell\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\dell\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\dell\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # Creating WordCloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud  # Import WordCloud class from the wordcloud library
wc = WordCloud(background_color='Black', width = 300, height=300, max_words=100, margin=2) # Giving BackGround Colour .
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None) # Giving fig Size
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
