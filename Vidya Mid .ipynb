# %% [markdown]
# # Installing Pandas with pip

# %%
pip install pandas  #Install Pandas using pip
# Out:
# Requirement already satisfied: pandas in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Pandas Library Import

# %%
import pandas as pd  #import pandas alias pd
df = pd.read_csv('/Users/yathisha/Downloads/data.csv') # Read the CSV file into a DataFrame, replace the path with your correct path

# %% [markdown]
# # Displaying DataFrame Head

# %%
df.head(20)  #Displaying the First 20 Rows of a DataFrame
# Out:
#            place  pop2022  growthRate          area country cca3  cca2  \
# 426    2305825.0  0.01068       30355       Lesotho     LSO   LS   426
# 328     808726.0  0.00517      214969        Guyana     GUY   GY   328
# 748    1201670.0  0.00788       17364      Eswatini     SWZ   SZ   748
# 410   51815810.0 -0.00028      100210   South Korea     KOR   KR   410
# 296     131232.0  0.01830         811      Kiribati     KIR   KI   296
# 583     114164.0  0.00913         702    Micronesia     FSM   FM   583
# 440    2750055.0 -0.01313       65300     Lithuania     LTU   LT   440
# 740     618040.0  0.00825      163820      Suriname     SUR   SR   740
# 643  144713314.0 -0.00268    17098242        Russia     RUS   RU   643
# 710   59893885.0  0.00845     1221037  South Africa     ZAF   ZA   710
# 804   39701739.0 -0.08798      603500       Ukraine     UKR   UA   804
# 112    9534954.0 -0.00451      207600       Belarus     BLR   BY   112
# 858    3422794.0 -0.00101      181034       Uruguay     URY   UY   858
# 499     627082.0 -0.00124       13812    Montenegro     MNE   ME   499
# 428    1850651.0 -0.01242       64559        Latvia     LVA   LV   428
# 705    2119844.0  0.00021       20273      Slovenia     SVN   SI   705
# 56    11655930.0  0.00383       30528       Belgium     BEL   BE    56
# 548     326740.0  0.02382       12189       Vanuatu     VUT   VU   548
# 496    3398366.0  0.01511     1564110      Mongolia     MNG   MN   496
# 398   19397998.0  0.01050     2724900    Kazakhstan     KAZ   KZ   398
#
#               ccn3           region           subregion  ...    density  \
# 426         Africa  Southern Africa  Sub-Saharan Africa  ...    75.9494
# 328  South America    South America       Latin America  ...     4.1083
# 748         Africa  Southern Africa  Sub-Saharan Africa  ...    69.8645
# 410           Asia     Eastern Asia               97600  ...  1375.0302
# 296        Oceania       Micronesia                 810  ...   419.6184
# 583        Oceania       Micronesia                 700  ...   422.4068
# 440         Europe  Northern Europe               62620  ...   113.7439
# 740  South America    South America       Latin America  ...     3.9618
# 643         Europe   Eastern Europe            16376870  ...    22.8864
# 710         Africa  Southern Africa  Sub-Saharan Africa  ...    49.3730
# 804         Europe   Eastern Europe              579400  ...   177.4724
# 112         Europe   Eastern Europe              202980  ...   121.6648
# 858  South America    South America       Latin America  ...    19.5566
# 499         Europe  Southern Europe               13450  ...   120.7541
# 428         Europe  Northern Europe               62230  ...    77.0237
# 705         Europe  Southern Europe             20136.4  ...   272.6603
# 56          Europe   Western Europe               30280  ...   996.9900
# 548        Oceania        Melanesia               12190  ...    69.4222
# 496           Asia     Eastern Asia           1557506.8  ...     5.6512
# 398           Asia     Central Asia             2699700  ...    18.6098
#
#      densityMi   Rank  rate2019male  rate2019female  rate2019both  \
# 426   196.7090  147.0         116.0            30.1          72.4
# 328    10.6406  164.0          63.0            17.4          40.3
# 748   180.9491  159.0          55.1             4.7          29.4
# 410    29.0000   40.2          16.9            28.6          39.0
# 296   192.0000   48.6           8.7            28.3          50.0
# 583   194.0000   43.2          12.7            28.2          41.0
# 440   141.0000   45.4           9.6            26.1          61.0
# 740    10.2610  170.0          38.8            11.8          25.4
# 643     9.0000   43.6           9.1            25.1          56.0
# 710   127.8761   24.0          37.6             9.8          23.5
# 804    38.0000   39.2           6.5            21.6          38.0
# 112    96.0000   36.7           7.7            21.2          42.0
# 858    50.6516  133.0          34.5             8.9          21.2
# 499   169.0000   31.7          10.4            21.0          30.0
# 428   151.0000   35.5           7.0            20.1          37.0
# 705   148.0000   31.4           8.3            19.8          33.0
# 56     81.0000   24.9          11.8            18.3          25.0
# 548   181.0000   28.1           7.6            18.0          28.0
# 496   134.0000   30.7           5.4            17.9          33.0
# 398    66.0000   29.0           6.8            17.6          39.0
#
#      rate2015male  rate2015female  rate2015both  rank
# 426           147              39            92   1.0
# 328            58              16            37   2.0
# 748            62               9            35   3.0
# 410            16              28             4   NaN
# 296             9              29             5   NaN
# 583            12              27             6   NaN
# 440            11              34             7   NaN
# 740            37              11            24   8.0
# 643            11              32             9   NaN
# 710            39               9            24  10.0
# 804             6              21            11   NaN
# 112             8              24            12   NaN
# 858            30               7            18  13.0
# 499            10              20            14   NaN
# 428             8              21            15   NaN
# 705             8              21            16   NaN
# 56             11              18            17   NaN
# 548             7              18            18   NaN
# 496             6              20            19   NaN
# 398             8              23            20   NaN
#
# [20 rows x 21 columns]

# %% [markdown]
# # Displaying DataFrame Columns

# %%
df.columns
# Out:
# Index(['place', 'pop2022', 'growthRate', 'area', 'country', 'cca3', 'cca2',
#        'ccn3', 'region', 'subregion', 'landAreaKm', 'density', 'densityMi',
#        'Rank', 'rate2019male', 'rate2019female', 'rate2019both',
#        'rate2015male', 'rate2015female', 'rate2015both', 'rank'],
#       dtype='object')

# %% [markdown]
# # Displaying DataFrame Data Types

# %%
df.dtypes
# Out:
# place             float64
# pop2022           float64
# growthRate          int64
# area               object
# country            object
# cca3               object
# cca2                int64
# ccn3               object
# region             object
# subregion          object
# landAreaKm        float64
# density           float64
# densityMi         float64
# Rank              float64
# rate2019male      float64
# rate2019female    float64
# rate2019both      float64
# rate2015male        int64
# rate2015female      int64
# rate2015both        int64
# rank              float64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 179 entries, 426 to 28
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   place           179 non-null    float64
#  1   pop2022         179 non-null    float64
#  2   growthRate      179 non-null    int64
#  3   area            179 non-null    object
#  4   country         179 non-null    object
#  5   cca3            178 non-null    object
#  6   cca2            179 non-null    int64
#  7   ccn3            179 non-null    object
#  8   region          179 non-null    object
#  9   subregion       179 non-null    object
#  10  landAreaKm      179 non-null    float64
#  11  density         179 non-null    float64
#  12  densityMi       179 non-null    float64
#  13  Rank            179 non-null    float64
#  14  rate2019male    179 non-null    float64
#  15  rate2019female  179 non-null    float64
#  16  rate2019both    179 non-null    float64
#  17  rate2015male    179 non-null    int64
#  18  rate2015female  179 non-null    int64
#  19  rate2015both    179 non-null    int64
#  20  rank            93 non-null     float64
# dtypes: float64(10), int64(5), object(6)
# memory usage: 30.8+ KB
# None

# %% [markdown]
# # Displaying DataFrame Information

# %%
df.describe()
# Out:
#               place     pop2022    growthRate        cca2    landAreaKm  \
# count  1.790000e+02  179.000000  1.790000e+02  179.000000  1.790000e+02
# mean   4.406868e+07    0.010976  7.420734e+05  432.223464  3.050609e+05
# std    1.550831e+08    0.014019  1.981464e+06  255.224412  7.921087e+05
# min    9.376300e+04   -0.087980  3.000000e+02    4.000000  2.181900e+00
# 25%    2.728024e+06    0.003835  3.004900e+04  216.000000  1.014134e+02
# 50%    1.014262e+07    0.010290  1.475700e+05  426.000000  1.861000e+03
# 75%    3.381742e+07    0.019350  5.845205e+05  654.000000  2.530150e+05
# max    1.425887e+09    0.069080  1.709824e+07  894.000000  8.358140e+06
#
#             density    densityMi        Rank  rate2019male  rate2019female  \
# count    179.000000   179.000000  179.000000    179.000000      179.000000
# mean     396.848204   275.695962   53.018994      9.064804        7.119553
# std     1653.403691   597.635356   51.939028     11.376856        6.475547
# min        3.118000     1.000000    0.000000      0.300000        0.400000
# 25%       50.134850    65.000000   14.150000      4.000000        2.700000
# 50%      127.101700   131.000000   29.000000      7.000000        4.100000
# 75%      305.750450   195.354500   79.000000      9.800000       10.950000
# max    21555.758400  4857.431200  196.000000    116.000000       30.100000
#
#        rate2019both  rate2015male  rate2015female  rate2015both        rank
# count    179.000000    179.000000      179.000000    179.000000   93.000000
# mean      12.773184      9.156425        7.312849     40.698324  103.247312
# std       11.883534     13.229101        7.252462     51.675180   44.430859
# min        0.000000      0.000000        0.000000      1.000000    1.000000
# 25%        5.300000      4.000000        2.000000      6.000000   77.000000
# 50%        8.000000      7.000000        4.000000     13.000000  107.000000
# 75%       17.000000     10.000000       10.500000     55.500000  137.000000
# max       72.400000    147.000000       39.000000    179.000000  175.000000

# %% [markdown]
# # Calculating and Displaying DataFrame Length

# %%
length = len(df)
print("Length of DataFrame:", length)
# Out:
# Length of DataFrame: 179

# %% [markdown]
# # Adding a New Column and Displaying Descriptive Statistics

# %%
df['length'] = df['subregion'].str.len() 
df.describe() # Display descriptive statistics for the 'length' column
# Out:
#               place     pop2022    growthRate        cca2    landAreaKm  \
# count  1.790000e+02  179.000000  1.790000e+02  179.000000  1.790000e+02
# mean   4.406868e+07    0.010976  7.420734e+05  432.223464  3.050609e+05
# std    1.550831e+08    0.014019  1.981464e+06  255.224412  7.921087e+05
# min    9.376300e+04   -0.087980  3.000000e+02    4.000000  2.181900e+00
# 25%    2.728024e+06    0.003835  3.004900e+04  216.000000  1.014134e+02
# 50%    1.014262e+07    0.010290  1.475700e+05  426.000000  1.861000e+03
# 75%    3.381742e+07    0.019350  5.845205e+05  654.000000  2.530150e+05
# max    1.425887e+09    0.069080  1.709824e+07  894.000000  8.358140e+06
#
#             density    densityMi        Rank  rate2019male  rate2019female  \
# count    179.000000   179.000000  179.000000    179.000000      179.000000
# mean     396.848204   275.695962   53.018994      9.064804        7.119553
# std     1653.403691   597.635356   51.939028     11.376856        6.475547
# min        3.118000     1.000000    0.000000      0.300000        0.400000
# 25%       50.134850    65.000000   14.150000      4.000000        2.700000
# 50%      127.101700   131.000000   29.000000      7.000000        4.100000
# 75%      305.750450   195.354500   79.000000      9.800000       10.950000
# max    21555.758400  4857.431200  196.000000    116.000000       30.100000
#
#        rate2019both  rate2015male  rate2015female  rate2015both        rank  \
# count    179.000000    179.000000      179.000000    179.000000   93.000000
# mean      12.773184      9.156425        7.312849     40.698324  103.247312
# std       11.883534     13.229101        7.252462     51.675180   44.430859
# min        0.000000      0.000000        0.000000      1.000000    1.000000
# 25%        5.300000      4.000000        2.000000      6.000000   77.000000
# 50%        8.000000      7.000000        4.000000     13.000000  107.000000
# 75%       17.000000     10.000000       10.500000     55.500000  137.000000
# max       72.400000    147.000000       39.000000    179.000000  175.000000
#
#            length
# count  179.000000
# mean    11.162011
# std      5.734922
# min      3.000000
# 25%      6.000000
# 50%     13.000000
# 75%     18.000000
# max     18.000000

# %% [markdown]
# # Displaying Descriptive Statistics for Categorical Columns

# %%
df.describe(include='O')
# Out:
#            area country cca3    ccn3          region           subregion
# count       179     179  178     179             179                 179
# unique      179     179  178       6              23                  91
# top     Lesotho     LSO   LS  Africa  Eastern Africa  Sub-Saharan Africa
# freq          1       1    1      52              17                  46

# %% [markdown]
# # Checking and Summing Missing Values in DataFrame

# %%
df.isna().sum()
# Out:
# place              0
# pop2022            0
# growthRate         0
# area               0
# country            0
# cca3               1
# cca2               0
# ccn3               0
# region             0
# subregion          0
# landAreaKm         0
# density            0
# densityMi          0
# Rank               0
# rate2019male       0
# rate2019female     0
# rate2019both       0
# rate2015male       0
# rate2015female     0
# rate2015both       0
# rank              86
# length             0
# dtype: int64

# %% [markdown]
# # Handling Missing Values in Specific Columns

# %%
df['cca3'].fillna('unknown', inplace=True)
df['rank'].fillna('unknown', inplace=True) # Fill missing values in 'speaker' and 'position' columns with 'unknown'
df.isna().sum() # Display the count of missing values after filling NaN values
# Out:
# place             0
# pop2022           0
# growthRate        0
# area              0
# country           0
# cca3              0
# cca2              0
# ccn3              0
# region            0
# subregion         0
# landAreaKm        0
# density           0
# densityMi         0
# Rank              0
# rate2019male      0
# rate2019female    0
# rate2019both      0
# rate2015male      0
# rate2015female    0
# rate2015both      0
# rank              0
# length            0
# dtype: int64

# %% [markdown]
# # Histogram Plot for Numerical Variable 'Rank'

# %%
import matplotlib.pyplot as plt

# Histogram for numerical variable 'Rank'
plt.figure(figsize=(8, 6))
plt.hist(df['Rank'], bins=20, color='skyblue', edgecolor='black')
plt.title('Rank')
plt.xlabel('Rank')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Box Plot for Numerical Variable 'Rank'

# %%
# Box plot for 'Rank'
plt.figure(figsize=(8, 6))
plt.boxplot(df['Rank'], vert=False)
plt.title('Boxplot of Rank')
plt.xlabel('Rank')
plt.show()

# %% [markdown]
# # Categorical Plot (Box Plot) using Seaborn

# %%
import seaborn as sns

# Creating a categorical plot (box plot) using seaborn
plt.figure(figsize=(12, 8))
sns.catplot(x='region', y='growthRate', data=df, kind='box', height=4, aspect=2)
plt.title('Categorical Plot of Engine HP by Vehicle Style')
plt.xlabel('Vehicle Style')
plt.ylabel('Engine HP')
plt.xticks(rotation=45)
plt.show()
# Out:
# /Users/yathisha/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Importing Regex Package

# %%
# Importing Regex Package
import regex as re
# Defining a Function to Pull Words
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %% [markdown]
# # Tokenizing Given Text

# %%
# Toknizing the Given Text
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# # Importing NLTK Package

# %%
# Importing nltk Package
import nltk

# %% [markdown]
# # Downloading Stop Words List

# %%
# Downloading all List of Stop Words
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'above', 'more', "needn't", 'about', 'such', "hadn't", "aren't", 'his', 'from', "weren't", 'if', 'than', 'no', "you'd", 'only', "haven't", 're', 'itself', 'couldn', 'her', 'nor', 'same', 'these', 'by', 'had', 'does', 'against', "you'll", 'other', 'under', 'ain', 'a', 'off', 'them', 'where', 'has', "mightn't", "won't", "that'll", 'yourself', "mustn't", 'don', 'am', 'hers', 'its', 'here', 'mightn', 'have', 'when', 'will', 'hadn', 'again', 'but', 'those', 'during', 'which', 'few', 'our', "wasn't", 'to', 'why', 'once', 'very', "isn't", 'of', 'there', 'the', 'myself', 'each', 'herself', "should've", 'wouldn', 'my', 'through', 'your', 'didn', 'doesn', 'so', "didn't", 'doing', 'just', 'after', 'yourselves', 'at', 'all', 'can', 'any', 'too', 'you', 'not', 'this', "couldn't", "you're", 'up', 'him', 'below', 'll', 'an', 'own', 'or', 's', 'haven', 'down', 'aren', 'she', 'o', 'between', 'needn', 'some', "shouldn't", 'then', 'been', 'how', 'wasn', 'further', "it's", 'weren', 'isn', 'that', "she's", 'whom', 'before', 'hasn', 'do', 'ma', 'are', 'themselves', 'their', 'won', 'we', 'who', 've', "doesn't", 'mustn', 'was', 'while', 'd', "don't", 'into', "wouldn't", 'm', 'being', 'as', 'i', 'out', 'for', 'is', 'with', "hasn't", 'now', 'in', 'were', 'and', 'me', 'he', 'ours', 'until', 'theirs', 'having', "you've", 'ourselves', 't', 'y', 'shan', 'because', 'what', 'it', 'yours', 'on', 'did', 'most', 'should', 'over', 'shouldn', 'himself', 'be', 'both', "shan't", 'they'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yathisha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Defining a Function to Remove Stop Words

# %%
# Defining a Function to Remove Stop Words
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# # Creating a Text Processing Pipeline

# %%
# Creating a Pipeline
pipeline = [str.lower, tokenize, remove_stop]

# Defining a Function to Run the Pipeline
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# # Applying Text Processing Pipeline to DataFrame Column

# %%
# Running the Pipeline
df['tokens'] = df['region'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# # Creating a New Column for Number of Tokens

# %%
#creating a New Column for the Number of Tokens
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#         place  pop2022  growthRate                              area country  \
# 678  227380.0  0.01915         964             Sao Tome and Principe     STP
# 670  103948.0 -0.00368         389  Saint Vincent and the Grenadines     VCT
# 308  125438.0  0.00665         344                           Grenada     GRD
# 52   281635.0  0.00155         430                          Barbados     BRB
# 28    93763.0  0.00584         442               Antigua and Barbuda     ATG
#
#     cca3  cca2           ccn3         region           subregion  ...  \
# 678   ST   678         Africa  Middle Africa  Sub-Saharan Africa  ...
# 670   VC   670  North America      Caribbean                 390  ...
# 308   GD   308  North America      Caribbean                 340  ...
# 52    BB    52  North America      Caribbean                 430  ...
# 28    AG    28  North America      Caribbean                 440  ...
#
#      rate2019male  rate2019female  rate2019both  rate2015male  rate2015female  \
# 678           2.2             0.8           1.5             2               0
# 670           0.6             1.0           5.0             0               3
# 308           0.7             0.7           0.0             0               0
# 52            0.3             0.6           0.0             0               0
# 28            0.8             0.4           0.0             0               0
#
#      rate2015both     rank  length            tokens  num_tokens
# 678             1    175.0      18  [middle, africa]           2
# 670           176  unknown       3       [caribbean]           1
# 308           177  unknown       3       [caribbean]           1
# 52            178  unknown       3       [caribbean]           1
# 28            179  unknown       3       [caribbean]           1
#
# [5 rows x 24 columns]

# %% [markdown]
# # Importing Counter Function

# %%
# importing a function Counter
from collections import Counter

tokens = tokenize("She likes my dogs and my dogs like my sofa.")
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'dogs': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# # Counting Token Occurrences Across DataFrame Column

# %%
# Printing the 5 Words Repeated the Most
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('africa', 52), ('asia', 45), ('europe', 39), ('western', 37), ('eastern', 32)]

# %% [markdown]
# # Creating a New DataFrame

# %%
# Creating a New Data Frame for Frequency Analysis 
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# # Sorting DataFrame

# %%
# Sorting the freq_df based on Frequency
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#           freq
# token
# africa      52
# asia        45
# europe      39
# western     37
# eastern     32
# southern    25
# america     22
# northern    18
# central     14
# south       13

# %% [markdown]
# # Printing Statistical Data

# %%
# Printing the Statistical Data of Frequency
freq_df.describe()
# Out:
#             freq
# count  19.000000
# mean   18.000000
# std    16.062378
# min     2.000000
# 25%     3.000000
# 50%    13.000000
# 75%    28.500000
# max    52.000000

# %% [markdown]
# # Printing Statistical Data

# %%
# Plotting a bar graph for most frequent words 
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(10,6))
ax.invert_yaxis()
ax.set(xlabel='value', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'value'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# # Creating Word Cloud for 'Region' Column

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Concatenate all 'Vehicle Style' strings into one string
text = ' '.join(df['region'].astype(str))

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Vehicle Styles')
plt.show()

# %% [markdown]
# # Importing Modules

# %%
# Importing the preprocessing module from the scikit-learn library
from sklearn import preprocessing
# Importing the Natural Language Toolkit (NLTK)
import nltk
# Downloading the opinion lexicon dataset from NLTK
nltk.download('opinion_lexicon')
# Out:
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     /Users/srijanagella/nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# True

# %% [markdown]
# # Importing Opinion Lexicon Dataset from NLTK

# %%
# Importing the opinion_lexicon dataset from the NLTK corpus module
from nltk.corpus import opinion_lexicon
# Importing the word_tokenize function from the NLTK tokenize module
from nltk.tokenize import word_tokenize

# %% [markdown]
# # Printing Total Number of Words,Positive Words and Negative Words in Opinion Lexicon Datase

# %%
# Printing the total number of words in the opinion_lexicon dataset
print('Total number of words in opinion lexicon', len(opinion_lexicon.words()))
# Printing examples of positive words in the opinion_lexicon dataset
print('Examples of positive words in opinion lexicon',opinion_lexicon.positive()[:10])
# Printing examples of negative words in the opinion_lexicon dataset
print('Examples of negative words in opinion lexicon',opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon 6789
# Examples of positive words in opinion lexicon ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']

# %% [markdown]
# # Downloading 'punkt' Tokenizer from NLTK

# %%
# Downloading the 'punkt' tokenizer from NLTK, which is required for word tokenization
nltk.download('punkt')
# Renaming the column 'reviewText' to 'text' for consistency and clarity
df.rename(columns={"reviewText": "text"}, inplace=True)
# Assigning positive and negative scores for sentiment analysis
pos_score = 1
neg_score = -1
# Creating an empty dictionary to store word scores for sentiment analysis
word_dict = {}
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/srijanagella/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Iterating through Positive Words in Opinion Lexicon

# %%
# Iterating through each positive word in the opinion lexicon and adding it to the word dictionary
for word in opinion_lexicon.positive():
    word_dict[word] = pos_score

# %% [markdown]
# # Iterating through Negative Words in Opinion Lexicon

# %%
# Iterating through each negative word in the opinion lexicon and adding it to the word dictionary
for word in opinion_lexicon.negative():
    word_dict[word] = neg_score

# %% [markdown]
# # Defining Sentiment Analysis Function using Bing Liu's Lexicon

# %%
# Define a function to calculate the sentiment score of a given text using Bing Liu's lexicon.
def bing_liu_score(text):
    sentiment_score = 0 # Initialize the sentiment score to zero.
    bag_of_words = word_tokenize(text.lower()) # Tokenize the text into individual words and convert to lowercase.
# Iterate over each word in the bag of words.
    for word in bag_of_words:
        # Check if the word exists in the word dictionary.
        if word in word_dict:
            sentiment_score += word_dict[word] # Add the sentiment score of the word to the overall sentiment score.
            return sentiment_score # Return the final sentiment score of the text.

# %% [markdown]
# # Filling Missing Values in 'region' Column,Bing Liu's Sentiment Score Calculation Function

# %%
# Fill missing values in the 'region' column with 'Southern Africa'
df['region'].fillna('Southern Africa', inplace=True)

# Assuming you have a function called bing_liu_score
def bing_liu_score(region):
    # Implement your logic here to compute the Bing Liu score based on the vehicle style
    # For demonstration, let's assume a constant score for 'Southern Africa'
    if region == 'Southern Africa':
        return 5
    else:
        return 0  # Fill with appropriate score for other regions

# Apply the function to create the 'Bing_Liu_Score' column
df['Bing_Liu_Score'] = df['region'].apply(bing_liu_score)

# %% [markdown]
# # Displaying Selected Columns in the First 10 Rows

# %%
# Displaying the first 10 rows of selected columns ('growthRate', 'text', 'Bing_Liu_Score')
df[['growthRate',"region", 'Bing_Liu_Score']].head(10)
# Out:
#      growthRate           region  Bing_Liu_Score
# 426       30355  Southern Africa               5
# 328      214969    South America               0
# 748       17364  Southern Africa               5
# 410      100210     Eastern Asia               0
# 296         811       Micronesia               0
# 583         702       Micronesia               0
# 440       65300  Northern Europe               0
# 740      163820    South America               0
# 643    17098242   Eastern Europe               0
# 710     1221037  Southern Africa               5

# %% [markdown]
# # Grouping DataFrame by 'growthRate' Column

# %%
# Grouping the DataFrame by the 'growthRate' column and calculating the mean of 'Bing_Liu_Score' for each group
df.groupby('growthRate').agg({'Bing_Liu_Score':'mean'})
# Out:
#             Bing_Liu_Score
# growthRate
# 300                    0.0
# 316                    0.0
# 344                    0.0
# 389                    0.0
# 430                    0.0
# ...                    ...
# 8515767                0.0
# 9372610                0.0
# 9706961                0.0
# 9984670                0.0
# 17098242               0.0
#
# [179 rows x 1 columns]
