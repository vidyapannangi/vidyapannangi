# %%
import pandas as pd
file = "C:/Users/DELL/Desktop/TextBasedAnalysis/un-general-debates-blueprint.csv"
df = pd.read_csv(file)
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %%
df = df.sample(frac=0.2)

# %%
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %%
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1501 entries, 3145 to 1346
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       1501 non-null   int64
#  1   year          1501 non-null   int64
#  2   country       1501 non-null   object
#  3   country_name  1501 non-null   object
#  4   speaker       1495 non-null   object
#  5   position      897 non-null    object
#  6   text          1501 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 93.8+ KB

# %%
df.describe()
# Out:
#            session         year
# count  1501.000000  1501.000000
# mean     49.409727  1994.409727
# std      12.895193    12.895193
# min      25.000000  1970.000000
# 25%      38.000000  1983.000000
# 50%      50.000000  1995.000000
# 75%      60.000000  2005.000000
# max      70.000000  2015.000000

# %%
df['length'] = df['text'].str.len()
df.describe()
# Out:
#            session         year        length
# count  1501.000000  1501.000000   1501.000000
# mean     49.409727  1994.409727  18048.972685
# std      12.895193    12.895193   7977.512997
# min      25.000000  1970.000000   3516.000000
# 25%      38.000000  1983.000000  12127.000000
# 50%      50.000000  1995.000000  16508.000000
# 75%      60.000000  2005.000000  22813.000000
# max      70.000000  2015.000000  63259.000000

# %%
df.describe(include='O')
# Out:
#        country country_name              speaker  \
# count     1501         1501                 1495
# unique     198          198                 1375
# top        LBR      Liberia  Mikheil Saakashvili
# freq        17           17                    4
#
#                             position  \
# count                            897
# unique                            56
# top     Minister for Foreign Affairs
# freq                             348
#
#                                                      text
# count                                                1501
# unique                                               1501
# top     Please accept Latvia's congratulations on your...
# freq                                                    1

# %%
df.isna().sum()
# Out:
# session           0
# year              0
# country           0
# country_name      0
# speaker           6
# position        604
# text              0
# length            0
# dtype: int64

# %%
df['speaker'].fillna('unknown', inplace=True)
df['position'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %%
df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper()

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 5760       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
#
#                                                    text  length
# 5760  I AM GRATEFUL FOR THE PRIVILEGE OF \nSPEAKING ...   16675
# 3207  FORTY-SEVEN YEARS AGO I WAS A YOUNG MAN OF 21,...   21105

# %%
df['length'].plot()
# Out:
# <Axes: >

# %%
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8)

# %%
import regex as re

# %%
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %%
import nltk

# %%
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'of', 'his', 'because', 'ain', 'few', 'there', 'were', 'having', 'here', 'hers', 'how', 'why', 'doesn', 'as', 'who', 'has', 'we', 'myself', 'where', 'between', 'does', "isn't", 'out', 'at', 'wasn', 'then', 've', 'a', 'further', 'than', 's', 'isn', 'her', 'o', 'couldn', "didn't", "mustn't", 'had', 'but', 'should', 't', 'he', 'own', 'when', 'didn', 'now', 'can', "doesn't", "don't", 'against', 'while', 'any', 'not', "won't", 'that', "should've", 'your', 'don', 'been', 'me', "she's", 'being', 'hadn', 'and', "shouldn't", 'wouldn', 'until', 'such', 'down', "that'll", 'very', 'through', 'ma', 'she', "hasn't", 'if', 'under', "mightn't", 'you', 'them', 'more', 'its', 'too', 'did', "you'd", 'just', 'i', "wouldn't", "it's", 'they', 'themselves', 'needn', 'during', 'am', 'yours', 'what', 'd', 'itself', "shan't", "haven't", 'our', 'above', 'no', 'so', 'be', 'into', 'mightn', 'their', 'both', "weren't", 'an', 'are', 'these', 'yourselves', 'm', "you'll", 'this', 'do', 'only', 'over', 'doing', 'have', 're', 'the', 'again', "couldn't", 'weren', 'about', 'nor', 'which', 'after', 'other', 'is', 'ours', 'from', 'some', 'll', 'each', 'theirs', 'herself', 'was', 'shan', 'most', "aren't", 'mustn', 'off', 'up', 'all', 'will', 'himself', 'whom', "hadn't", 'y', 'yourself', 'to', 'before', 'on', 'aren', 'it', 'my', "you're", "you've", 'once', 'won', 'him', 'ourselves', 'hasn', "wasn't", 'shouldn', 'those', 'with', 'below', 'haven', "needn't", 'or', 'by', 'in', 'same', 'for'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# %%
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %%
pipeline = [str.lower, tokenize, remove_stop]

# %%
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
        return tokens

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country country_name             speaker  \
# 7004       68  2013     IND        India      MANMOHAN SINGH
# 4569       55  2000     MLI         Mali       MODIBO SIDIBÉ
# 5239       59  2004     COG        Congo  MR. RODOLPHE ADADA
# 2790       45  1990     GRD      Grenada                NOEL
# 1346       35  1980     NOR       Norway          FRYDENLUND
#
#                           position  \
# 7004                PRIME MINISTER
# 4569  MINISTER FOR FOREIGN AFFAIRS
# 5239  MINISTER FOR FOREIGN AFFAIRS
# 2790                       UNKNOWN
# 1346                       UNKNOWN
#
#                                                    text  length  \
# 7004  LET ME FIRST OF ALL CONGRATULATE \nYOU, MR. PR...   10211
# 4569  AT THE\nOUTSET I SHOULD LIKE TO CONGRATULATE T...   14074
# 5239  THE\nELECTION OF MR. JEAN PING TO THE PRESIDEN...   10222
# 2790  ﻿MY GOVERNMENT VIEWS THIS FORTY-FIFTH SESSION ...   14712
# 1346  ﻿MR. PRESIDENT, IT GIVES ME GREAT PLEASURE TO ...   23594
#
#                                                  tokens  num_tokens
# 7004  let me first of all congratulate \nyou, mr. pr...       10211
# 4569  at the\noutset i should like to congratulate t...       14074
# 5239  the\nelection of mr. jean ping to the presiden...       10222
# 2790  ﻿my government views this forty-fifth session ...       14712
# 1346  ﻿mr. president, it gives me great pleasure to ...       23594

# %%
from collections import Counter

# %%
tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [(' ', 4142883), ('e', 2776605), ('t', 2206610), ('i', 1785148), ('n', 1783516)]

# %%
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %%
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#           freq
# token
#        4142883
# e      2776605
# t      2206610
# i      1785148
# n      1783516
# o      1782587
# a      1754806
# s      1360443
# r      1352764
# h       964347

# %%
freq_df.describe()
# Out:
#                freq
# count  1.710000e+02
# mean   1.584299e+05
# std    5.227707e+05
# min    1.000000e+00
# 25%    2.000000e+00
# 50%    1.600000e+01
# 75%    6.320500e+03
# max    4.142883e+06

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# %%
text = df.query("year==2013 and country=='IND'")['text'].values[0]

# %%
plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# Specify conditions
conditions = (df['year'] == 2013) & (df['country'] == 'IND')

# Check if there is data for the specified conditions
if df[conditions].empty:
    print("No data found for the given conditions.")
else:
    # Extract text for the specified conditions
    text = df[conditions]['text'].values[0]

    # Create and generate the word cloud
    wc = WordCloud(background_color='white', width=300, height=300, max_words=100, margin=2)
    wc.generate_from_text(text)

    # Display the word cloud
    plt.figure(figsize=(8, 8), facecolor=None)
    plt.imshow(wc)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()
